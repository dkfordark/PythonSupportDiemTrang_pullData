# %%
# !pip3 install app-store-scraper
# Out:
# Collecting app-store-scraper
#   Downloading app_store_scraper-0.3.5-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.7/dist-packages (from app-store-scraper) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->app-store-scraper) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->app-store-scraper) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->app-store-scraper) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests==2.23.0->app-store-scraper) (2.10)
# Installing collected packages: app-store-scraper
# Successfully installed app-store-scraper-0.3.5

# %%
import pandas as pd
import numpy as np
import random
from app_store_scraper import AppStore
from datetime import datetime
from datetime import date

# %%
import datetime
app_name = "replika".encode()
print(app_name)

d = datetime.date(2021, 12, 1)
d1 = datetime.date(2021, 1, 1)
print(d)

replika_us = AppStore(country="us", app_name=app_name, app_id='1158555867')
# replika_us.review(after_d)
replika_us.review(sleep=25, how_many=100, after=d1)
replika_us_reviews = pd.DataFrame(replika_us.reviews)
# Out:
# b'replika'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-32fa02c2a7b6> in <module>()
#       3 print(app_name)
#       4
# ----> 5 d = datetime.date(2021, 12, 1)
#       6 d1 = datetime(2021, 1, 1, 00, 00, 00, 00)
#       7 print(d)
#
# TypeError: descriptor 'date' requires a 'datetime.datetime' object but received a 'int'

# %%
replika_us_reviews.tail()

# %%
replika_us_reviews['date'].dtype

# %%
from google.colab import files

replika_us_reviews.to_csv('replika.reviews.csv')
files.download('replika.reviews.csv')
