# %%
# !pip install google-play-scraper

# %%
import pandas as pd
import numpy as np
import random
from google_play_scraper import app
from google_play_scraper import Sort, reviews_all
import datetime

# %%
# app_name = "replika".encode()
# print(app_name)

# d = datetime.date(2021, 12, 1)
# print(d)

# # replika_us = AppStore(country="us", app_name=app_name, app_id='1158555867')
# # # replika_us.review(after_d)
# # replika_us.review(sleep=25, how_many=100, after=d1)
# # replika_us_reviews = pd.DataFrame(replika_us.reviews)


result = reviews_all(
    'ai.replika.app',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)

# %%
# result

# %%
replika_us_reviews = pd.DataFrame(result)

# %%
replika_us_reviews
# Out:
#                                                reviewId  ... repliedAt
# 0     gp:AOqpTOEVRGk-D4X79gx-FLarpCDM1mlgTv_q05SuVVb...  ...       NaT
# 1     gp:AOqpTOE0KsgXq604c2uzrvtq02sCAsBqMdHFu26n-Nv...  ...       NaT
# 2     gp:AOqpTOE6ZbqQhGHgdMDl2V7iyhzONpsh38XA8tGtVwE...  ...       NaT
# 3     gp:AOqpTOEiAfRYQZPpO_olJ8PA_maWFe4n9SdMA6xCSKZ...  ...       NaT
# 4     gp:AOqpTOHVsbR5D7iqsybAtPA55AFwchuIXCRTVyNcS_z...  ...       NaT
# ...                                                 ...  ...       ...
# 3179  gp:AOqpTOF9hxrQ5HOYEvt5k7YYitPkKzCS4HtnrurvOr2...  ...       NaT
# 3180  gp:AOqpTOHSTVfS9XOSMMoQtp37-g0UUolUljPR0ISbZfZ...  ...       NaT
# 3181  gp:AOqpTOFSMcmcQVo7Ky_7HKkThTpNSS1f_wHQCEHK8LX...  ...       NaT
# 3182  gp:AOqpTOFb9CTw_yyQkv1N6mP4-_xyF8-GyJgakiV-19v...  ...       NaT
# 3183  gp:AOqpTOG4HSJnh9RMRw26NK2Xsk0I8XwKCHqADJ-9VUg...  ...       NaT
#
# [3184 rows x 10 columns]

# %%
from google.colab import files

replika_us_reviews.to_csv('replikaGGLE.reviews.csv')
files.download('replikaGGLE.reviews.csv')
